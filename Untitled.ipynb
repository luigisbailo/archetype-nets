# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

def normf(loc, scale):
    def normq(q):
        return norm.ppf(q,loc=loc,scale=scale)
    x = np.linspace(normq(0.01),
                 normq(0.99), 1000)
    y = norm.pdf(x,loc=loc,scale=scale)
    return x,y
x1,y1 = normf(0,1)
x2,y2 = normf(1,2)

ax.plot(x1, y1) #, 'r-', lw=5, alpha=0.6, label='norm pdf')
ax.plot(x2, y2) #, 'r-', lw=5, alpha=0.6, label='norm pdf')

var
# Out:
# array(1.)

# %%
x = np.linspace(-4,6,1000)
y1 = norm.pdf(x,0,1)
y2 = norm.pdf(x,1,2)
fig, ax = plt.subplots(1, 1)
ax.plot(x, y1) 
ax.plot(x, y2) 
ax.plot(x,(y1*y2)**0.5)

# %%
from nets_benchmarking import error_assessment as err
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

def get_zfixed ( dim_latent_space ):
            
    z_fixed_t = np.zeros([dim_latent_space, dim_latent_space + 1])

    for k in range(0, dim_latent_space):
        s = 0.0
        for i in range(0, k):
            s = s + z_fixed_t[i, k] ** 2

        z_fixed_t[k, k] = np.sqrt(1.0 - s)

        for j in range(k + 1, dim_latent_space + 1):
            s = 0.0
            for i in range(0, k):
                s = s + z_fixed_t[i, k] * z_fixed_t[i, j]

            z_fixed_t[k, j] = (-1.0 / float(dim_latent_space) - s) / z_fixed_t[k, k]
            z_fixed = np.transpose(z_fixed_t)
    
    return z_fixed
                            
points = err.points_in_simplex(get_zfixed(2),100)
xs,ys = points[:,0],points[:,1]
zs = norm.pdf(points,[0,0],[[1,0],[0,1]])
plt.plot(xs, ys, zs=0, zdir='z')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-792c1fc59055> in <module>
#      27 points = err.points_in_simplex(get_zfixed(2),100)
#      28 xs,ys = points[:,0],points[:,1]
# ---> 29 zs = norm.pdf(points,[0,0],[[1,0],[0,1]])
#      30 plt.plot(xs, ys, zs=0, zdir='z')
#      31 plt.show()
#
# ~/anaconda3/envs/tf_env/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1738         args = tuple(map(asarray, args))
#    1739         dtyp = np.find_common_type([x.dtype, np.float64], [])
# -> 1740         x = np.asarray((x - loc)/scale, dtype=dtyp)
#    1741         cond0 = self._argcheck(*args) & (scale > 0)
#    1742         cond1 = self._support_mask(x, *args) & (scale > 0)
#
# ValueError: operands could not be broadcast together with shapes (176819,2) (2,2)

# %%
from scipy.stats import multivariate_normal
#help(multivariate_normal)
pos = points
print(pos[:,0].shape)
rv = multivariate_normal([0.5, -0.2], [[0.001,0], [0,0.001]])
rv2 = multivariate_normal([0.5, -0.2,0.3], [[1,0,0], [0,1,0],[0,0,1]])
print(rv.pdf([0.5, -0.2]))
print(rv.pdf([0.27,-0.25]))
print(rv.pdf([0.2,-0.25]))
print(rv.pdf(pos).shape)
z = rv.pdf(pos)
z[z<1e-10] = 0
plt.scatter(pos[:,0], pos[:,1], z,marker='o')
plt.show()
# Out:
# (176819,)
# 159.15494309189532
# 1.4854669132219714e-10
# 1.3052699615459241e-18
# (176819,)

# %%
x = points_in_simplex(2,100)
#print(x)
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
print(np.array(tuple([1,2,3])))
# Out:
# [1 2 3]

# %%
np.matmul(np.array([[1,1,1],[2,2,2]]),np.array([[1,2,3]]).T)
# Out:
# array([[ 6],
#        [12]])

# %%
a = np.array([1,2,3])
b = np.array([1,2,3])
(a*b)**0.5
# Out:
# array([1., 2., 3.])

# %%
lst = ['ac','bc','aa']
[el for el in lst if 'a' in el]
# Out:
# ['ac', 'aa']

# %%
np.var([1,2,3])
# Out:
# 0.6666666666666666

# %%
np.std([1,2,3])
# Out:
# 0.816496580927726

# %%
import os
if os.path.exists('.git'): print('qq')
# Out:
# qq
