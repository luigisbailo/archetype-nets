# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
import tensorflow.keras as tfk
import tensorflow.keras.layers as tfkl
import tensorflow_probability.python.distributions as tfd

# %% [markdown]
# Three archetypes are defined on a two dimensional space.

# %%
anneal = 0
tryy = 0

archetypes_init = np.array([[1,0],
                  [2,2],
                  [0,1]])

# %%
def generate_data (archs, n_points, noise=0.1):
    
    k = len(archs)
    X,Y = archs.T 
    rand = np.random.uniform (0,1,[k,n_points])
    rand = (rand/np.sum(rand,axis=0)).T
    data = np.matmul(rand,archs)
    data = data + np.random.normal(0,noise,size=data.shape)
    Y0=np.linalg.norm(data-archs[0],axis=1)
    Y1=np.linalg.norm(data-archs[1],axis=1)
    Y2=np.linalg.norm(data-archs[2],axis=1)
    Y0=Y0/np.max(Y0)
    Y1=Y1/np.max(Y1)
    Y2=Y2/np.max(Y2)
    Y=np.concatenate((np.expand_dims(Y0,axis=1),np.expand_dims(Y1,axis=1),np.expand_dims(Y2,axis=1)),axis=1)
    
    return data, Y

# %% [markdown]
# Data is generated as a linear combination of the archetypes. Constrains on the weights are added so as to ensure that the generated data set is a convex mixture of the archetypes. Noise is then added, hence the resulting points can be defined outside the convex hull. Each data point has associated a side information vector  $\vec{Y}=(Y_0,Y_1,Y_2)$, where each component is the distance from one of the archetypes. Side information can be generalised to more complex functions. In the figure below we can see the three archetypes in blue, and the data set in different shades of red. Colors are obtained from the side information, that is used as entry for a RGB  color model.

# %%
x_train, y_train = generate_data (archetypes_init,100000,noise=0.1)
x_test, y_test = generate_data (archetypes_init,1000,noise=0.1)

data0,data1 = x_train.T
plt.scatter(data0, data1, color=y_train)
data0,data1 = archetypes_init.T
plt.scatter(data0, data1, color='blue')

# %%
def get_zfixed ( dim_latent_space ):
    
    z_fixed_t = np.zeros([dim_latent_space, dim_latent_space + 1])

    for k in range(0, dim_latent_space):
        s = 0.0
        for i in range(0, k):
            s = s + z_fixed_t[i, k] ** 2
  
        z_fixed_t[k, k] = np.sqrt(1.0 - s)

        for j in range(k + 1, dim_latent_space + 1):
            s = 0.0
            for i in range(0, k):
                s = s + z_fixed_t[i, k] * z_fixed_t[i, j]

            z_fixed_t[k, j] = (-1.0 / float(dim_latent_space) - s) / z_fixed_t[k, k]
            z_fixed = np.transpose(z_fixed_t)
                    
    return z_fixed

# %% [markdown]
# We use variational autoencoders to map the data set into a latent space. The neural network is constructed to force data in latent space to be defined within an arbitrary convex hull. We use a triangular convex hull as shown below.

# %%
zfixed = get_zfixed (2)
data0,data1 = zfixed.T
plt.scatter(data0, data1)

# %% [markdown]
# We construct a variational autoencoder that generates a mean $\mu$, and a standard deviation $\sigma$ for each data point. The point is then mapped into the latent space with a stochastic extraction from a Gaussian $\mathcal{N}(\mu,\,\sigma^{2})$, where $\mu$'s are by construction within a hull $z_{fixed}$.

# %%
original_dim = x_train.shape [1]
sideinfo_dim = y_train.shape [1]

x_train = np.array(np.reshape(x_train, [-1, original_dim]), dtype='float32')
x_test = np.array(np.reshape(x_test, [-1, original_dim]), dtype='float32')
y_train = np.array(np.reshape(y_train, [-1, sideinfo_dim]), dtype='float32')
y_test = np.array(np.reshape(y_test, [-1, sideinfo_dim]), dtype='float32')


# network parameters
intermediate_dim = 4
batch_size = 1024
latent_dim = 2
simplex_vrtxs = latent_dim + 1
epochs = 100



# encoder
input_x = tfk.Input(shape=(original_dim,), name='encoder_input_x', dtype='float32')

x = tfkl.Dense(intermediate_dim, activation='relu')(input_x)
x = tfkl.Dense(intermediate_dim, activation='relu')(x)
A = tfkl.Dense (simplex_vrtxs, activation='linear')(x)
A = tfkl.Dense (simplex_vrtxs, activation=tf.nn.softmax)(A)
B_t = tfkl.Dense (simplex_vrtxs, activation='linear')(x)
B = tf.nn.softmax(tf.transpose(B_t), axis=1)

z_fixed = get_zfixed (latent_dim)
z_fixed = tf.constant (z_fixed, dtype='float32')
mu = tf.matmul(A, z_fixed)
z_pred = tf.matmul(B,mu)
sigma = tfkl.Dense(latent_dim)(x)
t = tfd.Normal(mu,sigma)

input_y = tfk.Input(shape=(sideinfo_dim,), name='encoder_input_y', dtype='float32')
y = tf.identity(input_y)

encoder = tfk.Model([input_x,input_y], [t.sample(),mu,sigma, tf.transpose(B) ,y], name='encoder')
encoder.summary()



# decoder
latent_inputs = tfk.Input(shape=(latent_dim,), name='z_sampling')
input_y_lat = tfk.Input(shape=(sideinfo_dim,), name='encoder_input_y_lat')

x = tfkl.Dense(intermediate_dim, activation='relu')(latent_inputs)
x = tfkl.Dense(original_dim, activation='linear')(x)
x_hat = tfkl.Dense(original_dim, activation='linear')(x)

y = tfkl.Dense(intermediate_dim, activation='relu')(latent_inputs)
y = tfkl.Dense(intermediate_dim, activation='relu')(y)
y_hat = tfkl.Dense(sideinfo_dim, activation='linear')(y) 

decoder = tfk.Model([latent_inputs,input_y_lat], [x_hat,y_hat], name='decoder')
decoder.summary()


# annealing kl_loss parameter (milena):
kl_para = tfk.backend.variable(0.)
class NewCallback(tfk.callbacks.Callback):
    def __init__(self, kl_para):
        self.kl_para = kl_para       
    def on_epoch_end(self, epoch, logs={}):
        if epoch <= 100:
            tfk.backend.set_value(self.kl_para, tfk.backend.get_value(self.kl_para) + epoch/100)



# VAE
encoded = encoder([input_x,input_y])
outputs = decoder( [encoded[0],encoded[-1]])
vae = tfk.Model([input_x,input_y], outputs, name='vae')

reconstruction_loss = tfk.losses.mse (input_x, outputs[0])
class_loss = tfk.losses.mse ( input_y, outputs[1])
archetype_loss = tf.reduce_sum( tfk.losses.mse(z_fixed, z_pred))

kl_loss = 1 + sigma - tf.square(mu) - tf.exp(sigma)
kl_loss = tf.reduce_sum(kl_loss, axis=-1)
kl_loss *= -0.5

lambda_p = 1
nu_p = 1
if tryy == 1: 
    kl_para = 1
    vae_loss = tf.reduce_mean(nu_p*reconstruction_loss + lambda_p*class_loss + kl_para * kl_loss + archetype_loss)
if tryy == 0: 
    vae_loss = tf.reduce_mean(nu_p*reconstruction_loss + lambda_p*class_loss + kl_loss + archetype_loss)

    
vae.add_loss(vae_loss)
vae.compile(optimizer='adam')
vae.summary()

callbacks = [NewCallback(kl_para),] if anneal == 1 and tryy==1 else None # milena
vae.fit([x_train,y_train],  
        epochs=epochs,
        batch_size=batch_size,
        validation_data=([x_test,y_test],None),
        callbacks = callbacks) # milena



# archetypes
archetypes,_ = decoder ([z_pred, tf.zeros([3,3])])
get_archtypes = tfk.Model (input_x, [archetypes,z_pred] , name='get_zpred')
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_x (InputLayer)    [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 4)            12          encoder_input_x[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 4)            20          dense_72[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 3)            15          dense_73[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 3)            12          dense_74[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_12 (TensorFl [(None, 2)]          0           dense_75[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 2)            10          dense_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_18 (TensorFlo [(2,)]               0           tf_op_layer_MatMul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_19 (TensorFlo [(2,)]               0           dense_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_BroadcastArgs_6 (Te [(2,)]               0           tf_op_layer_Shape_18[0][0]
#                                                                  tf_op_layer_Shape_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_12 (TensorFl [(3,)]               0           tf_op_layer_BroadcastArgs_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_random_normal_6/Ran [(1, None, None)]    0           tf_op_layer_concat_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_random_normal_6/mul [(1, None, None)]    0           tf_op_layer_random_normal_6/Rando
# __________________________________________________________________________________________________
# tf_op_layer_random_normal_6 (Te [(1, None, None)]    0           tf_op_layer_random_normal_6/mul[0
# __________________________________________________________________________________________________
# tf_op_layer_mul_21 (TensorFlowO [(1, None, 2)]       0           tf_op_layer_random_normal_6[0][0]
#                                                                  dense_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_22 (TensorFlowO [(1, None, 2)]       0           tf_op_layer_mul_21[0][0]
#                                                                  tf_op_layer_MatMul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Shape_20 (TensorFlo [(3,)]               0           tf_op_layer_add_22[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 3)            15          dense_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [(2,)]               0           tf_op_layer_Shape_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_12 (Tenso [(3, None)]          0           dense_76[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_13 (TensorFl [(2,)]               0           tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softmax_6 (TensorFl [(3, None)]          0           tf_op_layer_transpose_12[0][0]
# __________________________________________________________________________________________________
# encoder_input_y (InputLayer)    [(None, 3)]          0
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_6 (TensorFl [(None, 2)]          0           tf_op_layer_add_22[0][0]
#                                                                  tf_op_layer_concat_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_13 (Tenso [(None, 3)]          0           tf_op_layer_Softmax_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Identity_6 (TensorF [(None, 3)]          0           encoder_input_y[0][0]
# ==================================================================================================
# Total params: 84
# Trainable params: 84
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# z_sampling (InputLayer)         [(None, 2)]          0
# __________________________________________________________________________________________________
# dense_78 (Dense)                (None, 4)            12          z_sampling[0][0]
# __________________________________________________________________________________________________
# dense_81 (Dense)                (None, 4)            12          z_sampling[0][0]
# __________________________________________________________________________________________________
# dense_79 (Dense)                (None, 2)            10          dense_78[0][0]
# __________________________________________________________________________________________________
# dense_82 (Dense)                (None, 4)            20          dense_81[0][0]
# __________________________________________________________________________________________________
# encoder_input_y_lat (InputLayer [(None, 3)]          0
# __________________________________________________________________________________________________
# dense_80 (Dense)                (None, 2)            6           dense_79[0][0]
# __________________________________________________________________________________________________
# dense_83 (Dense)                (None, 3)            15          dense_82[0][0]
# ==================================================================================================
# Total params: 75
# Trainable params: 75
# Non-trainable params: 0
# __________________________________________________________________________________________________
# WARNING:tensorflow:Model inputs must come from `tf.keras.Input` (thus holding past layer metadata), they cannot be the output of a previous non-Input layer. Here, a tensor specified as input to "vae" was not an Input tensor, it was generated by layer encoder_input_y.
# Note that input tensors are instantiated via `tensor = tf.keras.Input(shape)`.
# The tensor that caused the issue was: encoder_input_y_6:0
# WARNING:tensorflow:Output decoder missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to decoder.
# WARNING:tensorflow:Output decoder_1 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to decoder_1.
# Model: "vae"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input_x (InputLayer)    [(None, 2)]          0
# __________________________________________________________________________________________________
# encoder_input_y (InputLayer)    [(None, 3)]          0
# __________________________________________________________________________________________________
# encoder (Model)                 multiple             84          encoder_input_x[0][0]
#                                                                  encoder_input_y[0][0]
# __________________________________________________________________________________________________
# decoder (Model)                 [(None, 2), (None, 3 75          encoder[1][0]
#                                                                  encoder[1][4]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 4)            12          encoder_input_x[0][0]
# __________________________________________________________________________________________________
# dense_73 (Dense)                (None, 4)            20          dense_72[0][0]
# __________________________________________________________________________________________________
# dense_74 (Dense)                (None, 3)            15          dense_73[0][0]
# __________________________________________________________________________________________________
# dense_75 (Dense)                (None, 3)            12          dense_74[0][0]
# __________________________________________________________________________________________________
# dense_77 (Dense)                (None, 2)            10          dense_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_12 (TensorFl multiple             0           dense_75[0][0]
# __________________________________________________________________________________________________
# dense_76 (Dense)                (None, 3)            15          dense_73[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_23 (TensorFlowO [(None, 2)]          0           dense_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_4 (TensorFlo [(None, 2)]          0           tf_op_layer_MatMul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_transpose_12 (Tenso multiple             0           dense_76[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference_1 [(None, 2)]          0           decoder[1][0]
#                                                                  encoder_input_x[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference_1 [(None, 3)]          0           decoder[1][1]
#                                                                  encoder_input_y[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub_8 (TensorFlowOp [(None, 2)]          0           tf_op_layer_add_23[0][0]
#                                                                  tf_op_layer_Square_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_4 (TensorFlowOp [(None, 2)]          0           dense_77[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Softmax_6 (TensorFl multiple             0           tf_op_layer_transpose_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_16 (TensorFlow [(None,)]            0           tf_op_layer_SquaredDifference_12[
# __________________________________________________________________________________________________
# tf_op_layer_Mean_17 (TensorFlow [(None,)]            0           tf_op_layer_SquaredDifference_13[
# __________________________________________________________________________________________________
# tf_op_layer_sub_9 (TensorFlowOp [(None, 2)]          0           tf_op_layer_sub_8[0][0]
#                                                                  tf_op_layer_Exp_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_MatMul_13 (TensorFl [(3, 2)]             0           tf_op_layer_Softmax_6[0][0]
#                                                                  tf_op_layer_MatMul_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_23 (TensorFlowO [(None,)]            0           tf_op_layer_Mean_16[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_24 (TensorFlowO [(None,)]            0           tf_op_layer_Mean_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_9 (TensorFlowOp [(None,)]            0           tf_op_layer_sub_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_SquaredDifference_1 [(3, 2)]             0           tf_op_layer_MatMul_13[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_24 (TensorFlowO [(None,)]            0           tf_op_layer_mul_23[0][0]
#                                                                  tf_op_layer_mul_24[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_mul_22 (TensorFlowO [(None,)]            0           tf_op_layer_Sum_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_18 (TensorFlow [(3,)]               0           tf_op_layer_SquaredDifference_14[
# __________________________________________________________________________________________________
# tf_op_layer_add_25 (TensorFlowO [(None,)]            0           tf_op_layer_add_24[0][0]
#                                                                  tf_op_layer_mul_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_8 (TensorFlowOp [()]                 0           tf_op_layer_Mean_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_add_26 (TensorFlowO [(None,)]            0           tf_op_layer_add_25[0][0]
#                                                                  tf_op_layer_Sum_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_19 (TensorFlow [()]                 0           tf_op_layer_add_26[0][0]
# __________________________________________________________________________________________________
# add_loss_4 (AddLoss)            ()                   0           tf_op_layer_Mean_19[0][0]
# ==================================================================================================
# Total params: 159
# Trainable params: 159
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 100000 samples, validate on 1000 samples
# Epoch 1/100
# 100000/100000 [==============================] - 1s 9us/sample - loss: 2.7253 - val_loss: 2.2960
# Epoch 2/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 2.0122 - val_loss: 1.8357
# Epoch 3/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 1.7209 - val_loss: 1.6625
# Epoch 4/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 1.6190 - val_loss: 1.5970
# Epoch 5/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 1.5682 - val_loss: 1.5524
# Epoch 6/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 1.5268 - val_loss: 1.5104
# Epoch 7/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 1.4723 - val_loss: 1.4245
# Epoch 8/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 1.2990 - val_loss: 1.1721
# Epoch 9/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 1.0814 - val_loss: 1.0130
# Epoch 10/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.9344 - val_loss: 0.8123
# Epoch 11/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.7193 - val_loss: 0.6068
# Epoch 12/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.5805 - val_loss: 0.5171
# Epoch 13/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.5197 - val_loss: 0.4847
# Epoch 14/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4855 - val_loss: 0.4613
# Epoch 15/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4672 - val_loss: 0.4491
# Epoch 16/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.4566 - val_loss: 0.4444
# Epoch 17/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.4476 - val_loss: 0.4354
# Epoch 18/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.4380 - val_loss: 0.4272
# Epoch 19/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.4298 - val_loss: 0.4250
# Epoch 20/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4248 - val_loss: 0.4167
# Epoch 21/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.4184 - val_loss: 0.4149
# Epoch 22/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4151 - val_loss: 0.4094
# Epoch 23/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4096 - val_loss: 0.4048
# Epoch 24/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.4023 - val_loss: 0.4003
# Epoch 25/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3980 - val_loss: 0.4057
# Epoch 26/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3997 - val_loss: 0.4032
# Epoch 27/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3971 - val_loss: 0.4009
# Epoch 28/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3893 - val_loss: 0.3908
# Epoch 29/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3853 - val_loss: 0.3930
# Epoch 30/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3802 - val_loss: 0.3956
# Epoch 31/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3793 - val_loss: 0.4001
# Epoch 32/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3776 - val_loss: 0.3917
# Epoch 33/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3681 - val_loss: 0.3907
# Epoch 34/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3735 - val_loss: 0.3786
# Epoch 35/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3597 - val_loss: 0.3798
# Epoch 36/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3581 - val_loss: 0.3650
# Epoch 37/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3515 - val_loss: 0.3646
# Epoch 38/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3528 - val_loss: 0.3635
# Epoch 39/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3467 - val_loss: 0.3606
# Epoch 40/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3406 - val_loss: 0.3526
# Epoch 41/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3371 - val_loss: 0.3461
# Epoch 42/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3316 - val_loss: 0.3457
# Epoch 43/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3284 - val_loss: 0.3363
# Epoch 44/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3327 - val_loss: 0.3374
# Epoch 45/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3235 - val_loss: 0.3353
# Epoch 46/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3149 - val_loss: 0.3311
# Epoch 47/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3136 - val_loss: 0.3217
# Epoch 48/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3101 - val_loss: 0.3311
# Epoch 49/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.3080 - val_loss: 0.3145
# Epoch 50/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.3019 - val_loss: 0.3056
# Epoch 51/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2982 - val_loss: 0.3010
# Epoch 52/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2912 - val_loss: 0.2982
# Epoch 53/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2884 - val_loss: 0.2941
# Epoch 54/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2866 - val_loss: 0.2957
# Epoch 55/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2834 - val_loss: 0.2886
# Epoch 56/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2824 - val_loss: 0.2851
# Epoch 57/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2818 - val_loss: 0.2835
# Epoch 58/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2774 - val_loss: 0.2769
# Epoch 59/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2719 - val_loss: 0.2750
# Epoch 60/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2708 - val_loss: 0.2704
# Epoch 61/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2726 - val_loss: 0.2776
# Epoch 62/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2675 - val_loss: 0.2656
# Epoch 63/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2687 - val_loss: 0.2683
# Epoch 64/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2651 - val_loss: 0.2671
# Epoch 65/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2639 - val_loss: 0.2619
# Epoch 66/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2620 - val_loss: 0.2594
# Epoch 67/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2615 - val_loss: 0.2608
# Epoch 68/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2595 - val_loss: 0.2567
# Epoch 69/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2612 - val_loss: 0.2549
# Epoch 70/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2556 - val_loss: 0.2539
# Epoch 71/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2566 - val_loss: 0.2527
# Epoch 72/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2608 - val_loss: 0.2600
# Epoch 73/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2558 - val_loss: 0.2512
# Epoch 74/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2500 - val_loss: 0.2485
# Epoch 75/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2485 - val_loss: 0.2472
# Epoch 76/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2504 - val_loss: 0.2492
# Epoch 77/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2539 - val_loss: 0.2540
# Epoch 78/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2516 - val_loss: 0.2472
# Epoch 79/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2477 - val_loss: 0.2450
# Epoch 80/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2464 - val_loss: 0.2441
# Epoch 81/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2460 - val_loss: 0.2443
# Epoch 82/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2434 - val_loss: 0.2407
# Epoch 83/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2441 - val_loss: 0.2414
# Epoch 84/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2444 - val_loss: 0.2424
# Epoch 85/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2442 - val_loss: 0.2418
# Epoch 86/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2431 - val_loss: 0.2431
# Epoch 87/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2455 - val_loss: 0.2442
# Epoch 88/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2443 - val_loss: 0.2416
# Epoch 89/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2443 - val_loss: 0.2414
# Epoch 90/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2439 - val_loss: 0.2441
# Epoch 91/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2423 - val_loss: 0.2404
# Epoch 92/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2395 - val_loss: 0.2379
# Epoch 93/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2421 - val_loss: 0.2401
# Epoch 94/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2413 - val_loss: 0.2394
# Epoch 95/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2390 - val_loss: 0.2380
# Epoch 96/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2441 - val_loss: 0.2415
# Epoch 97/100
# 100000/100000 [==============================] - 0s 2us/sample - loss: 0.2401 - val_loss: 0.2380
# Epoch 98/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2369 - val_loss: 0.2350
# Epoch 99/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2363 - val_loss: 0.2347
# Epoch 100/100
# 100000/100000 [==============================] - 0s 3us/sample - loss: 0.2435 - val_loss: 0.2396

# %%
t,mu,sigma, B_t, y = encoder.predict([x_train,np.zeros(np.shape(y_train))])
archetypes_pred, z_pred = get_archtypes(x_train)

# %% [markdown]
# $\mu$'s are generated within an arbitrary triangular hull. Below we see the $\mu$'s in latent space in blue, and the vertexes of the arbitrarily chosen hull in orange.

# %%
dataX,dataY = mu.T
plt.scatter(dataX,dataY)
zfixed = get_zfixed (2)
data0,data1 = zfixed.T
plt.scatter(data0, data1,color='orange')

# %% [markdown]
# Using the data points initially generated we are able to reconstruct the initial points that have been taken as archetypes. Below, we see in blue the archetypes initailly defined, and in orange the predicted ones.

# %%
dataX,dataY = archetypes_init.T
plt.scatter(dataX,dataY,color='blue')

dataX,dataY = np.array(archetypes_pred).T
plt.scatter(dataX,dataY,color='orange')

# %% [markdown]
# We can feed the trained network with some test data and see that is able to reconstruct the data and side information after mapping into latent space.

# %%
x_pred, y_pred = vae.predict([x_test,np.zeros(np.shape(y_test))])
dataX,dataY = x_pred.T

if (np.min(y_pred)<0):
    y_pred += np.abs(np.min(y_pred))
if (np.min(y_pred)>1):
    y_pred /= np.abs(np.max(y_pred))

plt.scatter(dataX,dataY,color=y_pred)

# %% [markdown]
# Below we can see the original test data. If we compare the original data with the results of the variational encoder above, we can see that the encoder has the effect of a regularizer, i.e. the resulting effect is that noise is removed and data lie within the convex hull.

# %%
dataX,dataY = x_test.T
plt.scatter(dataX,dataY,color=y_test)
